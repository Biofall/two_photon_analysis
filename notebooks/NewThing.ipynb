# %%
# %load_ext autoreload
# %autoreload 2

# %%
from my_project_skeleton import utils, my_first_module as mfm

# %%
utils.which_exe()
# Out:
# /Users/averykrieger/Envs/test_env/bin/python

# %%
fig, ax = mfm.plot()
